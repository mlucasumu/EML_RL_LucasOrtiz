# %% [markdown]
# <a href="https://colab.research.google.com/github/mlucasumu/EML_RL_LucasOrtiz/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto de Aprendizaje por Refuerzo

# %% [markdown]
# En este repositorio se implementan y evalúan una gran variedad de algoritmos del ámbito del Aprendizaje por Refuerzo (AR), divididos en dos familias principales: por un lado, se ha estudiado el clásico problema del **bandido de los k brazos**, el cual sienta las bases del AR proporcionando un entorno simple en el que las acciones del agente no modifican el estado. Para ello, se han desarrollado algoritmos de tres familias: $\epsilon$-greedy, ascenso de gradiente y métodos UCB.
#
# Por otra parte, se han evaluado **problemas más complejos** en los que las acciones del agente sí tienen un impacto en el entorno, de manera que el estado del problema cambia en cada paso temporal. Este tipo de problemas se pueden resolver de dos maneras diferentes: mediante métodos tabulares, si el espacio de observaciones es finito, o mediante métodos aproximados, si el espacio de estados es infinito o excesivamente grande como para contenerlo en una matriz. En cuanto al primer tipo de métodos, podemos distinguir dos clases de algoritmos diferenciados, en particular, los métodos de Monte Carlo y los de Diferencias Temporales, cada uno con sus múltiples versiones. Con respecto a los métodos aproximados, se han analizado dos tipos de algoritmos diferentes: SARSA semi-gradiente y Deep Q-Learning.

# %% [markdown]
# Dado que el presente proyecto debe poder ser ejecutado en Google Colab, en la siguiente celda realizamos la preparación necesaria en caso de que vayamos a ejecutarlo en dicha plataforma. En caso de que estemos ejecutando en local, dentro de una copia del repositorio, no será necesario hacer ningún paso adicional.

# %%
import os

if os.getenv("COLAB_RELEASE_TAG"):
    print("Ejecutando en Colab")
    # !git clone https://github.com/mlucasumu/EML_RL_LucasOrtiz.git
else:
   print("Ejecutando en local")
# Out:
# Ejecutando en Colab
# Cloning into 'EML_RL_LucasOrtiz'...
# remote: Enumerating objects: 694, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 694 (delta 36), reused 35 (delta 35), pack-reused 637 (from 1)
# Receiving objects: 100% (694/694), 25.59 MiB | 12.18 MiB/s, done.
# Resolving deltas: 100% (399/399), done.

# %% [markdown]
# A continuación se incluyen los enlaces para navegar a las dos secciones en las que se divide el proyecto:
#
# 1. **[Bandido de k brazos](./k_brazos/main.ipynb)**
#
# 2. **[Entornos complejos](./entornos_complejos/main.ipynb)**
